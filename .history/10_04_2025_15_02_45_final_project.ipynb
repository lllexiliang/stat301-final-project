# %% [markdown]
# ## **Final Project Report: Group 3**
#
# **Group Members**:
# - Tara Ubovic
# - Dominique Chen
# - Lexi Liang
# - Piyush Awasthi
#
# **Course**: *STAT 301, Statistical Modelling for Data Science, 2024W2*
#
# **Date**: April 16, 2025

# %%
library(tidyverse)
library(infer)
library(broom)
library(leaps)
library(repr)
library(patchwork)
library(car)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
#
#
# The following object is masked from ‘package:purrr’:
#
#     some

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# **Background & Literature Review**
#
# One of the most frequently debated topics of conversations nowadays, especially in North America, is tipping culture, where servers' income significantly relies on the tips amount. Questions such as *How much is it appropriate to tip?*, *Who should tip more?*, *Should the value of your total bill amount affect how much you tip?* are among the most commonly asked ones, both by customers, and by researchers, government, and servers.
#
# Several studies have examined the patterns and trends of customers' tipping behavior, identifying a variety of factors that have proven to influence their tipping decisions. Lynn and McCall (2000) have discussed how service quality positively correlates with tipping amounts, alongside other factors, such as customer moods and social norms, and how societal expectations are mostly driving the tip amount rather than the service evaluation. On the other hand, Rogelberg et al. (1999) identified different types of factors that have been shown to influence the tipping decisions of customers, such as restaurant cleanliness, atmosphere, gender of the server, amount of alcohol consumed, total bill amount, as well as customer demographics. With all these studies, we can observe the multifaceted nature of tipping culture, alongside numerous social elements that influence tipping behavior, leading us to further analysis of real-world restaurant tipping dataset analysis.
#
# **Data Description**
#
# Our project aims to explore the tips dataset collected by a popular restaurant over a specific period of time (location and date were not explicitly stated), with the purpose of analyzing existing factors that influence tipping culture in this restaurant. It includes $244$ observations - unique transactions with $7$ different input variables: the total bill amount, tip given, the gender of the person paying, smoking preference, day of the week, time of day, and the size of the dining party.
#
# **Data Source**: Badole, S. (2024, June 3). Restaurant tips dataset. Kaggle. https://www.kaggle.com/datasets/saurabhbadole/restaurant-tips-dataset/data

# %% [markdown]
# 1. `total_bill`: numerical variable representing the total amount of the bill in dollars ($)
#
# 2. `tip`: numerical variable representing the total amount of the tip in dollars ($)
# 3. `sex`: categorical variable representing the gender of the person paying (*Male / Female*)
# 4. `smoker`: categorical variable representing the smoking preference (*Yes / No*)
# 5. `day`: categorical variable representing the day of the week (*Thursday / Friday / Saturday / Sunday*)
# 6. `time` : categorical variable representing the time of the day of the meal (*Lunch / Dinner*)
# 7. `size` : numerical variable representing the size of the dining party

# %% [markdown]
# **Research question**: *"How are the size of the dining party, the gender of the person paying, smoker status of customers, time and the day of the week associated with the tip percentage of the customer's bill in this popular restaurant?"*
#
# - Response variable: `tip percentage` = `tip` / `total_bill` × 100 (%)
# - Explanatory variables: `size`, `sex`, `smoker`, `time`, `day`

# %% [markdown]
# ## **Methods & Results**
#
# ### **Exploratory Data Analysis (EDA)**

# %%
# Developer: Dominique
# Contributor: Tara

# loading the datatset from public github link, showcasing head of the data
url <- "https://raw.githubusercontent.com/tarauboviccc/stat301_project/main/tips.csv" 
tip <- read.csv(url) 

head(tip,2)
cat("Table 1.1: Overview of the Restaurant Tip Dataset\n")
# Out:
#   total_bill tip  sex    smoker day time   size
# 1 16.99      1.01 Female No     Sun Dinner 2
# 2 10.34      1.66 Male   No     Sun Dinner 3
# Table 1.1: Overview of the Restaurant Tip Dataset

# %%
# Developers: Dominique, Tara

# removing the total_bill & tip variables, and creating the response variable - percentage tip
# converting categorical variables into factors
tip <- tip |>
        mutate(size = factor(size),
               sex = as.factor(sex),
               smoker = as.factor(smoker),
               day = as.factor(day),
               time = as.factor(time),
               tip_pct = (tip / total_bill) * 100)

# removing the variables total_bill and tip, since we have new variable tip_pct
tip <- tip |>
        select(-total_bill, -tip)

# Checking the dataset balance in terms of party sizes and days to spot the frequent occurences
size_count <- tip |>
    count(size)

day_count<-tip |>
    count(day)
head(tip,2)
cat("Table 1.2: Overview of tip dataset after removing tip and total_bill")
size_count
cat("Table 1.2: Count of observations by party size\n")
day_count
cat("Table 1.3: Count of observations by day of the week\n")
# Out:
#   sex    smoker day time   size tip_pct
# 1 Female No     Sun Dinner 2     5.944673
# 2 Male   No     Sun Dinner 3    16.054159
# Table 1.2: Overview of tip dataset after removing tip and total_bill
#   size n
# 1 1      4
# 2 2    156
# 3 3     38
# 4 4     37
# 5 5      5
# 6 6      4
# Table 1.1: Count of observations by party size
#   day  n
# 1 Fri  19
# 2 Sat  87
# 3 Sun  76
# 4 Thur 62
# Table 1.2: Count of observations by day of the week

# %% [markdown]
# **Observations**:
# - We observed a limited number of observations for party sizes 1, 5, and 6, as well as an imbalance between the high count for party size 2 compared to sizes 3 and 4. Therefore, there is a risk that certain party sizes appear only in the training or only in the test set; In order to address this, we will group the party sizes  into two levels: 2 and 2+.
# - We observed that Friday and Thursday have the fewest number observations, while Saturday and Sunday have much higher counts; To reduce imbalance in data and simplify this variable, we decided to group day into two levels: weekends (`wknd`) for Saturday and Sunday, and weekdays (`wkyd`) for Thursday and Friday.

# %%
# Developer: Dominique

# grouping categories for party size and day with fewer observations together in larger groups, as described above
tip <- tip %>%
    mutate(size = fct_collapse(size, 
                               '2-' = c('1', '2'),   # party sizes of 1 and 2 to group '2-'
                               '2+' = c('3', '4', '5', '6')),  # party sizes of 3, 4, 5, 6 to group '2+'
           day = fct_collapse(day,
                              'wkyd' = c('Fri', 'Thur'),  # Friday & Thursday to group 'wkyd'
                              'wknd' = c('Sat', 'Sun')))  # Saturday & Sunday to group 'wknd'


tip %>% count(size, sort = TRUE)
cat("Table 1.4: Count of observations by party size with 2 new factors\n")

tip %>% count(day, sort = TRUE)
cat("Table 1.5: Count of observations by day of the week with 2 new factors\n")
# Out:
#   size n
# 1 2-   160
# 2 2+    84
# Table 1.3: Count of observations by party size with 2 new factors
#   day  n
# 1 wknd 163
# 2 wkyd  81
# Table 1.4: Count of observations by day of the week with 2 new factors

# %%
# Developers: Dominique, Lexi
# Contributor: Tara
options(repr.plot.width = 10, repr.plot.height = 10)

# distribution of tip percentage for different times of the day, throughout different days
tip_explore_plot <- tip |>
    ggplot(aes(x = day, y = tip_pct, color = time))+
    geom_point()+
    stat_summary(fun = mean, geom = "crossbar", width = 0.5, color = "black")+
    scale_color_manual(values = c("Lunch" = "lightgreen", "Dinner" = "darkgreen")) +
    labs(title = "Tip Percentage vs. Day & Time of week",
         x = "Day of the Week",
         y = "Tip Percentage")

# distribution of tip percentages based on smoker status (yes / no)
tip_box_plot <- tip |>
  ggplot(aes(x = smoker, y = tip_pct, fill = smoker)) +
  geom_boxplot() +
  stat_summary(fun = mean, geom = "point", shape = 20, size = 3, color = "black") +
  scale_fill_manual(values = c("Yes" = "black", "No" = "lightgray")) +
  labs(title = "Average Tip Percentage vs. Smoker Status",
       x = "Smoker Status",
       y = "Tip Percentage")

# distribution of tip percentages based on party sizes & time of the day
tips_vis <- tip %>%
    ggplot(aes(x = time, y = tip_pct,fill = size)) +
    geom_boxplot(outlier.shape = NA) +
    labs(title = "Tip Percentage by Party Size and Time of Day",
         x = "Time of day",
         y = "Tip Percentage",
         fill = "Party Size") 

# distribution of tip percentages based on gender paying the bill
gender_violin_plot <- tip |>
  ggplot(aes(x = sex, y = tip_pct, fill = sex)) +
  geom_violin(trim = FALSE, alpha = 0.5) +
  geom_boxplot(width = 0.1, outlier.shape = NA) +
  scale_fill_manual(values = c("Female" = "salmon", "Male" = "lightblue"))+
  labs(title = "Tip Percent Distribution by Payer's Sex",
       x = "Sex",
       y = "Tip Percentage")
       

combined_plot <-  (tip_explore_plot + tip_box_plot) / (tips_vis + gender_violin_plot) +
    plot_annotation(title = "Figure 1.1: Tip Percentage Distributions Based on Different Factors")
combined_plot
# Out:
# plot without title

# %% [markdown]
# **Observations**:
# - Higher number of financial transactions happened on weekend during dinner hours.
# - The tip percentage doesn't differ much depending on the smoker status of the party, meaning it's similar for smokers and non-smokers.
# - Tipping percentage does not vary significantly between different party sizes.
# - Males and females tip a similar percentage on average, but males exhibit more outliers in their tipping behavior.

# %% [markdown]
# As shown in Figure 1.2(left), the tip percentage distribution is right-skewed with extreme outliers above 60%. After discussing with the TA, we decided to filter out these outliers to better approximate a normal distribution. As seen in Figure 1.2(right), after removing outliers, our data distribution becomes more concentrated and roughly symmetric.

# %%
# Developer: Tara
options(repr.plot.width = 10, repr.plot.height = 7)
# looking at the distribution of the raw data to identify extreme outliers
outlier_plot<-ggplot(tip, aes(x = tip_pct)) + 
    geom_histogram(bins = 30, fill = "orange") +
    labs(x = "Tip Percentage (%)", y = "Count") +
    theme_minimal() 

# identifying potential outliers in `tip_pct`column by using the mean +/- 3 * sd formula
mean_tip <- mean(tip$tip_pct)
sd_tip <- sd(tip$tip_pct)
upper_bound <- mean_tip + 3 * sd_tip
lower_bound <- mean_tip - 3 * sd_tip

# creating a new subset with filtered outliers
tip <- subset(tip, tip_pct <= upper_bound & tip_pct>=lower_bound)

remove_outlier_plot<-ggplot(tip, aes(x = tip_pct)) + 
    geom_histogram(bins = 30, fill = "blue") +
    labs(x = "Tip Percentage (%)", y = "Count") + 
    theme_minimal() 

combined_plots <-  (outlier_plot + remove_outlier_plot) +
    plot_annotation(title = "Figure 1.2: Tip Percentage Distributions before and after removing outliers")
combined_plots
# Out:
# plot without title

# %% [markdown]
# ### **Methods: Plan**

# %% [markdown]
# We decided to use forward selection to build a linear regression model that infers tip percentage using a set of relevant explanatory variables. Forward selection method allows us to identify and select only the most relevant variables while maintaining model interpretability.

# %% [markdown]
# **Method Reasoning**:
# - **Interpretability** - unlike Lasso or Ridge, forward selection offers a clear, step-by-step view of variable inclusion, making it easier to observe and justify the significance of each predictor included in the model.
# - **Effective method for low-dimensional data** - with only five candidate predictor variables, forward selection method is both computationally efficient and avoids unnecessary model complexity.
# - **Overfitting prevention** - by stopping variable inclusion when additional predictors do not significantly improve model performance, forward selection helps prevent overfitting the model, which is one of the main concerns for us in this setting, given our limited sample size and number of predictor variables.

# %% [markdown]
# **Method Assumptions**:
# - **Linearity**: Method assumes a linear relationship between explanatory variables and response (tip percentage) variable.
# - **Independence**: Method assumes independent observations (e.g., tip percentage is not affected by other customers or previous tip percentages of same customer).
# - **Normality of Residuals**: Method assumes that the residuals are approximately normally distributed.
# - **Homoscedasticity**: Method assumes that variance of residuals is constant across all levels of the predictor variables.
# - **Multicollinearity**: Before applying the method, we checked VIFs, and ensured all values were below 5, indicating low multicollinearity among predictor variables.

# %% [markdown]
# **Method Limitations & Weaknesses**:
# - **Non-linear Relationships**: If the relationship between the explanatory variables and the response variable is in reality non-linear, the model will fail to capture important patterns, resulting in biased results.
# - **Overfitting Risk**: Despite forward selection's built-in stopping rule when adding new variables isn't improving model's performance, the small sample size still has overfitting risk, and it may retain variables that don't generalize well to new data.

# %% [markdown]
# We first split the data into a selection set (30%) and training set (70%), where we used the selection set for feature selection.

# %%
# Developer: Lexi
# Contributer: Dominique, Tara
set.seed(123)

# splitting the data based on 70-30% ratio for selection and training
training_tips <- tip %>%
    slice_sample(prop = 0.7, replace = FALSE)
selection_tips <- tip %>%
    anti_join(training_tips, by = names(tip))

head(training_tips,2)
cat("Number of rows in the training set: ", nrow(training_tips), "\n")
cat("Table 1.4: First two rows of the training set\n")

head(selection_tips,2)
cat("Number of rows in the selection set: ", nrow(selection_tips), "\n")
cat("Table 1.5: First two rows of the selection set\n")
# Out:
#   sex    smoker day  time   size tip_pct
# 1 Female No     wknd Dinner 2-   19.492158
# 2 Male   Yes    wknd Dinner 2-    8.364236
# Number of rows in the training set:  169
# Table 1.4: First two rows of the training set
#   sex  smoker day  time   size tip_pct
# 1 Male No     wknd Dinner 2+   16.05416
# 2 Male No     wknd Dinner 2+   16.65873
# Number of rows in the selection set:  73
# Table 1.5: First two rows of the selection set

# %% [markdown]
# **Feature Selection**
#
# We decide to use Forward selection method with all explanatory variables in order to identify the most significant predictors. As previously mentioned, this feature selection method adds one variable at each step, then evaluates the model's fit based on the change in adjusted $R^2$, $p$-value, or sometimes even change in $R^2$. This approach allows us to keep the most significant predictors, whilst maintaining model simplicity and interpretability. After that evaluation, we selected that most improved the adjusted $R^2$.

# %%
# Developer: Dominique
# Contributors: Lexi, Tara

# using regsubsets() for evaluating model fit with new variable at each step, identifying the most significant predictor variables 
tip_forward_sel <- regsubsets(
    x = tip_pct ~ ., 
    nvmax = 5,
    data = selection_tips,
    method = "forward")

tip_forward_sel_summary <- summary(tip_forward_sel)
tip_forward_sel_summary
cat("Table 1.6: Forward selection results summary\n")
# Out:
# Subset selection object
# Call: regsubsets.formula(x = tip_pct ~ ., nvmax = 5, data = selection_tips,
#     method = "forward")
# 5 Variables  (and intercept)
#           Forced in Forced out
# sexMale       FALSE      FALSE
# smokerYes     FALSE      FALSE
# daywknd       FALSE      FALSE
# timeLunch     FALSE      FALSE
# size2+        FALSE      FALSE
# 1 subsets of each size up to 5
# Selection Algorithm: forward
#          sexMale smokerYes daywknd timeLunch size2+
# 1  ( 1 ) " "     " "       " "     " "       "*"
# 2  ( 1 ) " "     "*"       " "     " "       "*"
# 3  ( 1 ) "*"     "*"       " "     " "       "*"
# 4  ( 1 ) "*"     "*"       " "     "*"       "*"
# 5  ( 1 ) "*"     "*"       "*"     "*"       "*"
# Table 1.6: Forward selection results summary

# %% [markdown]
# **Observations**:
# - Method added four predictor variables to the model: `sexMale`, `smokerYes`, `daywknd`, and `size2+`, since they improved fittness of the model, evaluated by the adjusted $R^2$ and corresponding p-values.
# - Additionally, we can see that the variable `timeLunch` was excluded later on from the model, since it didn't significantly improved model's performance.

# %%
# Developer: Dominique
# Contributors: Lexi, Tara

# creating tidy dataframe summarizing number of predictors, and corresponding adj R^2 values from the results
tip_forward_summary_df <- tibble(
    n_input_variables = 1:5,
    ADJ.R2 = tip_forward_sel_summary$adjr2)

tip_forward_summary_df
cat("Table 1.7: Forward selection summary of number of variables and adjusted R-squared\n")
# Out:
#   n_input_variables ADJ.R2
# 1 1                 0.04365484
# 2 2                 0.05544900
# 3 3                 0.05565937
# 4 4                 0.05030278
# 5 5                 0.03615969
# Table 1.7: Forward selection summary of number of variables and adjusted R-squared

# %% [markdown]
# **Observation**:
# As the number of input variables increases, the value of adjusted $R^2$ initially increases, but then begins to slowly decrease when adding more and more variables. This suggests that the inclusion of additional variables beyond the second one does not provide a significant improvement in model fit and may indicate potential overfitting

# %%
# Developer: Dominique
# Contributors: Tara, Lexi
options(repr.plot.width = 7, repr.plot.height = 6)

# plotting the change of adjusted R^2 when adding new variables one by one during forward selection, showing the trends

variable_names <- c("Sex (Male)", "Weekend Day", "Lunch Time", "Party Size (2+)", "Smoker (Yes)")
ggplot(tip_forward_summary_df, aes(x = n_input_variables, y = ADJ.R2)) +
    geom_line(group = 1, color = "blue") +
    geom_point(color = "red", size = 4) +
    scale_x_continuous(
        breaks = tip_forward_summary_df$n_input_variables, 
        labels = variable_names) +
    labs(
        x = "Predictor Variables Added (in order)",
        y = "Adjusted R²",
        theme_minimal() +
        theme(axis.text.x = element_text(angle = 45, hjust = 1))) + 
        cat("Figure 1.3: Change in Adjusted R² with Forward Selection\n")
# Out:
# Figure 1.3: Change in Adjusted R² with Forward Selection
# plot without title

# %% [markdown]
# The figure 1.3 confirms once again that the change in adjusted $R^2$ as the predictor variables are being added during forward selection. It shows that model's initial improvement when 2 variables are considered, and later on slow decrease suggesting potential overfitting with further including predictors.

# %% [markdown]
# **Fitting the Multiple Linear Regression Model on Training Set**
#
# And finally, we fit a multiple linear regression (MLR) model on the training_tips dataset, using the predictor variables selected during the forward selection process. This model estimates the relationship between the predictor variables and the response variable - `tip percentage`. This allows us to look into the association of each predictor on the response variable, as well as to evaluate the model's predictive performance on test / unseen data.

# %%
# Developer: Dominique
# Contributor: Tara

# fitting mlr model while using selected variables (sex and day) to predict tip_pct with training dataset
tip_lm <- lm(tip_pct ~ sex + day, data = training_tips)

summary(tip_lm)
cat("Table 1.8: Model summary of the MLR model using sex and day as predictors\n")
# Out:
# Call:
# lm(formula = tip_pct ~ sex + day, data = training_tips)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -11.8378  -2.9896  -0.4428   3.1169  16.5499
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  16.4237     0.7838  20.955   <2e-16 ***
# sexMale      -0.6217     0.7895  -0.787    0.432
# daywknd      -0.4004     0.8052  -0.497    0.620
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.748 on 166 degrees of freedom
# Multiple R-squared:  0.00627,	Adjusted R-squared:  -0.005702
# F-statistic: 0.5237 on 2 and 166 DF,  p-value: 0.5933
# Table 1.8: Model summary of the MLR model using sex and day as predictors

# %% [markdown]
# **Interpretation**:
# - With a p-value of 0.5933, this means that our model is not significantly different from the intercept-only model.
# - Multiple R-squared value of $0.00627$ indicates that the model is currently explaining only $0.6$% of the variance in tip percentage variable, which is very low.
#
# **Conclusion**: Model summary indicates that model does not provide a strong fit to the data currently, as can be seen in statistical significance of its predictor variables (sex and day), meaning they are not as efficient in explaining the variation in tip percentage variable. However, given the current size of dataset, this remains the best solution available.

# %%
# checking multicollinearity using vif
vif_model <- vif(tip_lm)
vif_model
cat("Table 1.9: VIF values for MLR model\n")
# Out:
#     sex     day
# 1.03519 1.03519
# Table 1.9: VIF values for MLR model

# %% [markdown]
# **Interpretation**:
# VIF values of ~$1.035$ for both sex and day variables suggest that we don't have to worry about multicollinearity in our model (Considering the degrees of freedom of the variables are 1, GVIF = VIF).

# %% [markdown]
# ## **Discussion**
# > In this section, you’ll interpret the results you obtained in the previous section with respect to the main question/goal of your project.
#
# > Summarize what you found and the implications/impact of your findings.
# If relevant, discuss whether your results were what you expected to find.
# Discuss how your model could be improved;
# Discuss future questions/research this study could lead to.

# %% [markdown]
# ACTION:Interpret results for the poor - adj.r^2

# %% [markdown]
# ACTION: Summarize findings; is it what we expect?

# %% [markdown]
# ACTION:How can we improve?

# %% [markdown]
# ACTION:future research this leads to.

# %% [markdown]
# ## **References**

# %% [markdown]
# Lynn, M., & McCall, M. (2000). Gratitude and gratuity: A meta-analysis of research on the service–tipping relationship. *The Journal of Socio-Economics*, 29(2), 203–214. https://doi.org/10.1016/S1053-5357(00)00062-7
#
# Rogelberg, S. G., Ployhart, R. E., Balzer, W. K., & Yonker, R. D. (1999). Using policy capturing to examine tipping decisions. *Journal of Applied Social Psychology*, 29(12), 2567–2590. https://doi.org/10.1111/j.1559-1816.1999.tb00126.x
